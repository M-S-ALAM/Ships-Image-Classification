# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
data=pd.read_csv('/content/gdrive/MyDrive/train/train.csv')
data.head()
# Out:
#          image  category
# 0  2823080.jpg         1
# 1  2870024.jpg         1
# 2  2662125.jpg         2
# 3  2900420.jpg         3
# 4  2804883.jpg         2

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

# %%
ship= {'Cargo': 1, 
        'Military': 2, 
        'Carrier': 3, 
        'Cruise': 4, 
        'Tankers': 5}

# reverse the ship type dictionary

ship = dict([[v,k] for k,v in ship.items()])
data['Target']=data['category'].map(ship).astype('category')
data.head()
# Out:
#          image  category    Target
# 0  2823080.jpg         1     Cargo
# 1  2870024.jpg         1     Cargo
# 2  2662125.jpg         2  Military
# 3  2900420.jpg         3   Carrier
# 4  2804883.jpg         2  Military

# %%
plt.figure(figsize=(10,10))
sns.countplot(y=data['Target'].values)
plt.xticks(rotation=90)
# Out:
# (array([   0.,  250.,  500.,  750., 1000., 1250., 1500., 1750., 2000.,
#         2250.]), <a list of 10 Text major ticklabel objects>)

# %%
from sklearn.model_selection import train_test_split
train_df,test_df=train_test_split(data,test_size=0.25,random_state=42)

# %%
import tensorflow as tf
from keras import backend as K
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.models import *
from tensorflow.keras.preprocessing.image import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.applications.efficientnet import *

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input,validation_split=0.2)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input)

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (4689, 3)
# (1563, 3)

# %%
from keras.preprocessing.image import ImageDataGenerator
INPUT_PATH='/content/gdrive/MyDrive/train/images'
train_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    directory=INPUT_PATH,
    x_col='image',
    y_col='Target',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='training'
)

val_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    directory=INPUT_PATH,
    x_col='image',
    y_col='Target',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='validation'
)

test_images = test_generator.flow_from_dataframe(
    dataframe=test_df,
    directory=INPUT_PATH,
    x_col='image',
    y_col='Target',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 3752 validated image filenames belonging to 5 classes.
# Found 937 validated image filenames belonging to 5 classes.
# Found 1563 validated image filenames belonging to 5 classes.

# %%
import random as rn
import cv2
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=rn.randint(0,data.shape[0])
        img = cv2.imread(INPUT_PATH+'/'+data.iloc[l][0],cv2.IMREAD_COLOR)
        img = cv2.resize(img, (224,224))
        ax[i,j].imshow(img)
        ax[i,j].set_title('Ship: '+data.iloc[l][2])
plt.tight_layout()

# %% [markdown]
# #Pretrained EfficentNet

# %%
def create_model(input_shape):
  model = Sequential()
  model.add(Conv2D(1024, kernel_size=(3,3), strides=(2,2), activation="relu", input_shape=(224,224, 3), padding='same'))
  model.add(MaxPool2D(pool_size=(2, 2)))
  model.add(BatchNormalization()) 

  model.add(Conv2D(512, kernel_size=(3,3), strides=(2,2), activation="relu", padding='same'))
  model.add(MaxPool2D(pool_size=(2, 2)))
  model.add(BatchNormalization()) 

  model.add(Conv2D(256, kernel_size=(3,3), strides=(2,2), activation="relu", padding='same'))
  model.add(MaxPool2D(pool_size=(3, 3)))
  model.add(BatchNormalization()) 

  model.add(Conv2D(128, kernel_size=(3,3), strides=(1,1), activation="relu", padding='same'))
  model.add(MaxPool2D(pool_size=(2,2)))
  model.add(BatchNormalization())

  model.add(Flatten())
  model.add(Dense(256, activation='relu'))
  model.add(Dropout(rate=0.2))
  model.add(Dense(120, activation='relu'))
  model.add(Dropout(rate=0.2))
  model.add(Dense(60, activation='relu'))
  model.add(Dropout(rate=0.2))
  model.add(Dense(5, activation='softmax'))
  return model

# %%
model=create_model(input_shape=(224,224,3))

# %%
tf.keras.utils.plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='TB')

# %%
def f1_score(y_true, y_pred):
    def recall(y_true, y_pred):
        """Recall metric.
        Only computes a batch-wise average of recall.
        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        """Precision metric.
        Only computes a batch-wise average of precision.
        Computes the precision, a metric for multi-label classification of
        how many selected items are relevant.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
model.compile(loss='categorical_crossentropy',
               optimizer='adam',
               metrics=['accuracy',f1_score])

# %%
from tensorflow.keras.callbacks import *
import os
# %reload_ext tensorboard
filepath="/content/gdrive/MyDrive/Flower dataset/"
checkpoint = ModelCheckpoint(monitor='val_f1_score', mode='max', filepath=filepath, verbose=1, save_best_only=True, save_weights_only=False)
earlystop = EarlyStopping(monitor = 'val_f1_score',  mode="max",min_delta = 0, patience = 6,verbose = 1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_f1_score', factor = 0.25, patience = 3, verbose = 1,min_lr=0.000001)
import datetime
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
#tensorboard = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)
tensorboard = TensorBoard(log_dir=logdir, histogram_freq=0, write_graph=True, write_grads=False, write_images=False)
callbacks = [reduce_lr,tensorboard,checkpoint,earlystop]

# %%
STEP_SIZE_TRAIN=train_images.n//train_images.batch_size
STEP_SIZE_VALID=val_images.n//val_images.batch_size
STEP_SIZE_TEST=test_images.n//test_images.batch_size
history=model.fit_generator(generator=train_images,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=test_images,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=25,callbacks=callbacks)
# Out:
# Epoch 1/25
# 117/117 [==============================] - ETA: 0s - loss: 1.4567 - accuracy: 0.3718 - f1_score: 0.1664
# Epoch 00001: val_f1_score improved from -inf to 0.18103, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 117/117 [==============================] - 1562s 13s/step - loss: 1.4567 - accuracy: 0.3718 - f1_score: 0.1664 - val_loss: 2.1555 - val_accuracy: 0.1810 - val_f1_score: 0.1810 - lr: 0.0010
# Epoch 2/25
# 117/117 [==============================] - ETA: 0s - loss: 1.1931 - accuracy: 0.4919 - f1_score: 0.3871
# Epoch 00002: val_f1_score improved from 0.18103 to 0.19567, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 117/117 [==============================] - 28s 241ms/step - loss: 1.1931 - accuracy: 0.4919 - f1_score: 0.3871 - val_loss: 1.7824 - val_accuracy: 0.1950 - val_f1_score: 0.1957 - lr: 0.0010
# Epoch 3/25
# 117/117 [==============================] - ETA: 0s - loss: 0.9884 - accuracy: 0.6038 - f1_score: 0.5372
# Epoch 00003: val_f1_score did not improve from 0.19567
# 117/117 [==============================] - 25s 210ms/step - loss: 0.9884 - accuracy: 0.6038 - f1_score: 0.5372 - val_loss: 3.1631 - val_accuracy: 0.1832 - val_f1_score: 0.1832 - lr: 0.0010
# Epoch 4/25
# 117/117 [==============================] - ETA: 0s - loss: 0.8566 - accuracy: 0.6535 - f1_score: 0.6191
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00004: val_f1_score improved from 0.19567 to 0.37050, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 117/117 [==============================] - 29s 245ms/step - loss: 0.8566 - accuracy: 0.6535 - f1_score: 0.6191 - val_loss: 1.7195 - val_accuracy: 0.3825 - val_f1_score: 0.3705 - lr: 0.0010
# Epoch 5/25
# 117/117 [==============================] - ETA: 0s - loss: 0.6524 - accuracy: 0.7374 - f1_score: 0.7227
# Epoch 00005: val_f1_score improved from 0.37050 to 0.53429, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 117/117 [==============================] - 29s 244ms/step - loss: 0.6524 - accuracy: 0.7374 - f1_score: 0.7227 - val_loss: 1.2146 - val_accuracy: 0.5345 - val_f1_score: 0.5343 - lr: 2.5000e-04
# Epoch 6/25
# 117/117 [==============================] - ETA: 0s - loss: 0.5388 - accuracy: 0.7777 - f1_score: 0.7705
# Epoch 00006: val_f1_score improved from 0.53429 to 0.60710, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 117/117 [==============================] - 28s 242ms/step - loss: 0.5388 - accuracy: 0.7777 - f1_score: 0.7705 - val_loss: 1.0030 - val_accuracy: 0.6110 - val_f1_score: 0.6071 - lr: 2.5000e-04
# Epoch 7/25
# 117/117 [==============================] - ETA: 0s - loss: 0.4551 - accuracy: 0.8137 - f1_score: 0.8078
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00007: val_f1_score improved from 0.60710 to 0.70231, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 117/117 [==============================] - 29s 244ms/step - loss: 0.4551 - accuracy: 0.8137 - f1_score: 0.8078 - val_loss: 0.7634 - val_accuracy: 0.7047 - val_f1_score: 0.7023 - lr: 2.5000e-04
# Epoch 8/25
# 117/117 [==============================] - ETA: 0s - loss: 0.3559 - accuracy: 0.8578 - f1_score: 0.8535
# Epoch 00008: val_f1_score improved from 0.70231 to 0.72719, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 117/117 [==============================] - 31s 264ms/step - loss: 0.3559 - accuracy: 0.8578 - f1_score: 0.8535 - val_loss: 0.7205 - val_accuracy: 0.7231 - val_f1_score: 0.7272 - lr: 6.2500e-05
# Epoch 9/25
# 117/117 [==============================] - ETA: 0s - loss: 0.3164 - accuracy: 0.8758 - f1_score: 0.8687
# Epoch 00009: val_f1_score improved from 0.72719 to 0.74382, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 117/117 [==============================] - 29s 246ms/step - loss: 0.3164 - accuracy: 0.8758 - f1_score: 0.8687 - val_loss: 0.7224 - val_accuracy: 0.7392 - val_f1_score: 0.7438 - lr: 6.2500e-05
# Epoch 10/25
# 117/117 [==============================] - ETA: 0s - loss: 0.2858 - accuracy: 0.8820 - f1_score: 0.8789
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00010: val_f1_score improved from 0.74382 to 0.74814, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 117/117 [==============================] - 28s 242ms/step - loss: 0.2858 - accuracy: 0.8820 - f1_score: 0.8789 - val_loss: 0.7093 - val_accuracy: 0.7425 - val_f1_score: 0.7481 - lr: 6.2500e-05
# Epoch 11/25
# 117/117 [==============================] - ETA: 0s - loss: 0.2605 - accuracy: 0.8995 - f1_score: 0.8960
# Epoch 00011: val_f1_score did not improve from 0.74814
# 117/117 [==============================] - 25s 211ms/step - loss: 0.2605 - accuracy: 0.8995 - f1_score: 0.8960 - val_loss: 0.7055 - val_accuracy: 0.7457 - val_f1_score: 0.7468 - lr: 1.5625e-05
# Epoch 12/25
# 117/117 [==============================] - ETA: 0s - loss: 0.2411 - accuracy: 0.9094 - f1_score: 0.9063
# Epoch 00012: val_f1_score did not improve from 0.74814
# 117/117 [==============================] - 25s 211ms/step - loss: 0.2411 - accuracy: 0.9094 - f1_score: 0.9063 - val_loss: 0.7049 - val_accuracy: 0.7435 - val_f1_score: 0.7451 - lr: 1.5625e-05
# Epoch 13/25
# 117/117 [==============================] - ETA: 0s - loss: 0.2268 - accuracy: 0.9094 - f1_score: 0.9093
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 00013: val_f1_score improved from 0.74814 to 0.74877, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 117/117 [==============================] - 29s 245ms/step - loss: 0.2268 - accuracy: 0.9094 - f1_score: 0.9093 - val_loss: 0.7191 - val_accuracy: 0.7457 - val_f1_score: 0.7488 - lr: 1.5625e-05
# Epoch 14/25
# 117/117 [==============================] - ETA: 0s - loss: 0.2253 - accuracy: 0.9156 - f1_score: 0.9137
# Epoch 00014: val_f1_score did not improve from 0.74877
# 117/117 [==============================] - 25s 210ms/step - loss: 0.2253 - accuracy: 0.9156 - f1_score: 0.9137 - val_loss: 0.7170 - val_accuracy: 0.7457 - val_f1_score: 0.7460 - lr: 3.9063e-06
# Epoch 15/25
# 117/117 [==============================] - ETA: 0s - loss: 0.2093 - accuracy: 0.9239 - f1_score: 0.9225
# Epoch 00015: val_f1_score did not improve from 0.74877
# 117/117 [==============================] - 25s 211ms/step - loss: 0.2093 - accuracy: 0.9239 - f1_score: 0.9225 - val_loss: 0.7213 - val_accuracy: 0.7457 - val_f1_score: 0.7466 - lr: 3.9063e-06
# Epoch 16/25
# 117/117 [==============================] - ETA: 0s - loss: 0.2198 - accuracy: 0.9159 - f1_score: 0.9153
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 00016: val_f1_score did not improve from 0.74877
# 117/117 [==============================] - 25s 210ms/step - loss: 0.2198 - accuracy: 0.9159 - f1_score: 0.9153 - val_loss: 0.7237 - val_accuracy: 0.7457 - val_f1_score: 0.7448 - lr: 3.9063e-06
# Epoch 17/25
# 117/117 [==============================] - ETA: 0s - loss: 0.2186 - accuracy: 0.9177 - f1_score: 0.9141
# Epoch 00017: val_f1_score did not improve from 0.74877
# 117/117 [==============================] - 25s 210ms/step - loss: 0.2186 - accuracy: 0.9177 - f1_score: 0.9141 - val_loss: 0.7238 - val_accuracy: 0.7478 - val_f1_score: 0.7482 - lr: 1.0000e-06
# Epoch 18/25
# 117/117 [==============================] - ETA: 0s - loss: 0.2100 - accuracy: 0.9228 - f1_score: 0.9200
# Epoch 00018: val_f1_score did not improve from 0.74877
# 117/117 [==============================] - 25s 211ms/step - loss: 0.2100 - accuracy: 0.9228 - f1_score: 0.9200 - val_loss: 0.7248 - val_accuracy: 0.7468 - val_f1_score: 0.7483 - lr: 1.0000e-06
# Epoch 19/25
# 117/117 [==============================] - ETA: 0s - loss: 0.2189 - accuracy: 0.9180 - f1_score: 0.9172
# Epoch 00019: val_f1_score did not improve from 0.74877
# 117/117 [==============================] - 25s 210ms/step - loss: 0.2189 - accuracy: 0.9180 - f1_score: 0.9172 - val_loss: 0.7260 - val_accuracy: 0.7468 - val_f1_score: 0.7468 - lr: 1.0000e-06
# Epoch 00019: early stopping

# %%
model.save_weights("/content/gdrive/MyDrive/ships/model.h5")

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 5))
plt.subplot(121)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1_score')
plt.ylabel('F1_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation f1_score
plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
results = model.evaluate(test_images, verbose=0)

print("    Test Loss: {:.5f}".format(results[0]))
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
#     Test Loss: 0.71618
# Test Accuracy: 75.24%

# %%
pred = model.predict(test_images)
pred = np.argmax(pred,axis=1)

# Map the label
labels = (train_images.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]

# %%
from sklearn.metrics import classification_report
y_test = list(test_df.Target)
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#        Cargo       0.69      0.73      0.71       520
#      Carrier       0.91      0.83      0.87       239
#       Cruise       0.86      0.81      0.84       203
#     Military       0.78      0.87      0.83       284
#      Tankers       0.64      0.57      0.60       317
#
#     accuracy                           0.75      1563
#    macro avg       0.78      0.77      0.77      1563
# weighted avg       0.75      0.75      0.75      1563

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
y_test = list(test_df.Target)
cf_matrix = confusion_matrix(y_test, pred,normalize='true')
plt.figure(figsize = (10,6))
cmap=sns.light_palette("green")
sns.heatmap(cf_matrix,cmap=cmap, annot=True, xticklabels = sorted(set(y_test)), yticklabels = sorted(set(y_test)))
plt.title('Normalized Confusion Matrix')
plt.show()

# %%
fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(15, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(INPUT_PATH+'/'+test_df.image.iloc[i]))
    ax.set_title(f"True: {test_df.Target.iloc[i]}\nPredicted: {pred[i]}")
plt.tight_layout()
plt.show()

# %%
# Efficentnet model works Train Accuracy is approx 100% and Test Accuracy 95%.

# %% [markdown]
# ## Apply Augmentation

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input,
    validation_split=0.2,featurewise_center=False,
                             featurewise_std_normalization=False,
                             rotation_range=10,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             horizontal_flip=True,
                             vertical_flip=True,
                             zoom_range=(0.8, 1.2),
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input,featurewise_center=False,
                             featurewise_std_normalization=False,
                             rotation_range=10,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             horizontal_flip=True,
                             vertical_flip=True,
                             zoom_range=(0.8, 1.2),
)

# %%
train_images_aug = train_generator.flow_from_dataframe(
    dataframe=train_df,
    directory=INPUT_PATH,
    x_col='image',
    y_col='Target',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=256,
    shuffle=True,
    seed=42,
    subset='training'
)

val_images_aug = train_generator.flow_from_dataframe(
    dataframe=train_df,
    directory=INPUT_PATH,
    x_col='image',
    y_col='Target',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=256,
    shuffle=True,
    seed=42,
    subset='validation'
)

test_images_aug = test_generator.flow_from_dataframe(
    dataframe=test_df,
    directory=INPUT_PATH,
    x_col='image',
    y_col='Target',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=256,
    shuffle=False
)
# Out:
# Found 3752 validated image filenames belonging to 5 classes.
# Found 937 validated image filenames belonging to 5 classes.
# Found 1563 validated image filenames belonging to 5 classes.

# %%
model.compile(loss='categorical_crossentropy',
               optimizer='adam',
               metrics=['accuracy',f1_score])

# %%
from tensorflow.keras.callbacks import *
import os
# %reload_ext tensorboard
filepath="/content/gdrive/MyDrive/Flower dataset/"
checkpoint = ModelCheckpoint(monitor='val_f1_score', mode='max', filepath=filepath, verbose=1, save_best_only=True, save_weights_only=False)
earlystop = EarlyStopping(monitor = 'val_f1_score',  mode="max",min_delta = 0, patience = 6,verbose = 1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_f1_score', factor = 0.25, patience = 3, verbose = 1,min_lr=0.000001)
import datetime
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
#tensorboard = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)
tensorboard = TensorBoard(log_dir=logdir, histogram_freq=0, write_graph=True, write_grads=False, write_images=False)
callbacks = [reduce_lr,tensorboard,checkpoint,earlystop]

# %%
STEP_SIZE_TRAIN=train_images.n//train_images.batch_size
STEP_SIZE_VALID=val_images.n//val_images.batch_size
STEP_SIZE_TEST=test_images.n//test_images.batch_size
history=model.fit_generator(generator=train_images,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=test_images,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=25,callbacks=callbacks)
# Out:
# Epoch 1/25
# 117/117 [==============================] - ETA: 0s - loss: 0.7411 - accuracy: 0.7296 - f1_score: 0.7112
# Epoch 00001: val_f1_score improved from -inf to 0.62263, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 117/117 [==============================] - 30s 247ms/step - loss: 0.7411 - accuracy: 0.7296 - f1_score: 0.7112 - val_loss: 1.1194 - val_accuracy: 0.6325 - val_f1_score: 0.6226 - lr: 0.0010
# Epoch 2/25
# 117/117 [==============================] - ETA: 0s - loss: 0.5852 - accuracy: 0.7742 - f1_score: 0.7677
# Epoch 00002: val_f1_score did not improve from 0.62263
# 117/117 [==============================] - 25s 211ms/step - loss: 0.5852 - accuracy: 0.7742 - f1_score: 0.7677 - val_loss: 1.4313 - val_accuracy: 0.5841 - val_f1_score: 0.5828 - lr: 0.0010
# Epoch 3/25
# 117/117 [==============================] - ETA: 0s - loss: 0.5293 - accuracy: 0.7970 - f1_score: 0.7940
# Epoch 00003: val_f1_score improved from 0.62263 to 0.70933, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 117/117 [==============================] - 28s 242ms/step - loss: 0.5293 - accuracy: 0.7970 - f1_score: 0.7940 - val_loss: 0.8009 - val_accuracy: 0.7198 - val_f1_score: 0.7093 - lr: 0.0010
# Epoch 4/25
# 117/117 [==============================] - ETA: 0s - loss: 0.4570 - accuracy: 0.8282 - f1_score: 0.8284
# Epoch 00004: val_f1_score did not improve from 0.70933
# 117/117 [==============================] - 25s 210ms/step - loss: 0.4570 - accuracy: 0.8282 - f1_score: 0.8284 - val_loss: 0.9942 - val_accuracy: 0.6853 - val_f1_score: 0.6823 - lr: 0.0010
# Epoch 5/25
# 117/117 [==============================] - ETA: 0s - loss: 0.3997 - accuracy: 0.8487 - f1_score: 0.8444
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00005: val_f1_score did not improve from 0.70933
# 117/117 [==============================] - 25s 210ms/step - loss: 0.3997 - accuracy: 0.8487 - f1_score: 0.8444 - val_loss: 0.8848 - val_accuracy: 0.6821 - val_f1_score: 0.6823 - lr: 0.0010
# Epoch 6/25
# 117/117 [==============================] - ETA: 0s - loss: 0.1904 - accuracy: 0.9390 - f1_score: 0.9343
# Epoch 00006: val_f1_score improved from 0.70933 to 0.76421, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 117/117 [==============================] - 29s 244ms/step - loss: 0.1904 - accuracy: 0.9390 - f1_score: 0.9343 - val_loss: 0.7165 - val_accuracy: 0.7586 - val_f1_score: 0.7642 - lr: 2.5000e-04
# Epoch 7/25
# 117/117 [==============================] - ETA: 0s - loss: 0.1107 - accuracy: 0.9621 - f1_score: 0.9619
# Epoch 00007: val_f1_score did not improve from 0.76421
# 117/117 [==============================] - 25s 211ms/step - loss: 0.1107 - accuracy: 0.9621 - f1_score: 0.9619 - val_loss: 0.8036 - val_accuracy: 0.7489 - val_f1_score: 0.7515 - lr: 2.5000e-04
# Epoch 8/25
# 117/117 [==============================] - ETA: 0s - loss: 0.0774 - accuracy: 0.9739 - f1_score: 0.9737
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00008: val_f1_score did not improve from 0.76421
# 117/117 [==============================] - 25s 211ms/step - loss: 0.0774 - accuracy: 0.9739 - f1_score: 0.9737 - val_loss: 1.0012 - val_accuracy: 0.7500 - val_f1_score: 0.7529 - lr: 2.5000e-04
# Epoch 9/25
# 117/117 [==============================] - ETA: 0s - loss: 0.0598 - accuracy: 0.9801 - f1_score: 0.9791
# Epoch 00009: val_f1_score improved from 0.76421 to 0.77425, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 117/117 [==============================] - 28s 243ms/step - loss: 0.0598 - accuracy: 0.9801 - f1_score: 0.9791 - val_loss: 0.8974 - val_accuracy: 0.7737 - val_f1_score: 0.7743 - lr: 6.2500e-05
# Epoch 10/25
# 117/117 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9903 - f1_score: 0.9900
# Epoch 00010: val_f1_score improved from 0.77425 to 0.77920, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 117/117 [==============================] - 28s 242ms/step - loss: 0.0369 - accuracy: 0.9903 - f1_score: 0.9900 - val_loss: 0.8662 - val_accuracy: 0.7812 - val_f1_score: 0.7792 - lr: 6.2500e-05
# Epoch 11/25
# 117/117 [==============================] - ETA: 0s - loss: 0.0301 - accuracy: 0.9938 - f1_score: 0.9932
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00011: val_f1_score did not improve from 0.77920
# 117/117 [==============================] - 25s 210ms/step - loss: 0.0301 - accuracy: 0.9938 - f1_score: 0.9932 - val_loss: 0.9141 - val_accuracy: 0.7748 - val_f1_score: 0.7755 - lr: 6.2500e-05
# Epoch 12/25
# 117/117 [==============================] - ETA: 0s - loss: 0.0221 - accuracy: 0.9957 - f1_score: 0.9960
# Epoch 00012: val_f1_score did not improve from 0.77920
# 117/117 [==============================] - 25s 210ms/step - loss: 0.0221 - accuracy: 0.9957 - f1_score: 0.9960 - val_loss: 0.9218 - val_accuracy: 0.7726 - val_f1_score: 0.7776 - lr: 1.5625e-05
# Epoch 13/25
# 117/117 [==============================] - ETA: 0s - loss: 0.0252 - accuracy: 0.9938 - f1_score: 0.9936
# Epoch 00013: val_f1_score did not improve from 0.77920
# 117/117 [==============================] - 25s 210ms/step - loss: 0.0252 - accuracy: 0.9938 - f1_score: 0.9936 - val_loss: 0.9405 - val_accuracy: 0.7737 - val_f1_score: 0.7763 - lr: 1.5625e-05
# Epoch 14/25
# 117/117 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 0.9949 - f1_score: 0.9938
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 00014: val_f1_score improved from 0.77920 to 0.77971, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 117/117 [==============================] - 28s 243ms/step - loss: 0.0245 - accuracy: 0.9949 - f1_score: 0.9938 - val_loss: 0.9436 - val_accuracy: 0.7802 - val_f1_score: 0.7797 - lr: 1.5625e-05
# Epoch 15/25
# 117/117 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 0.9954 - f1_score: 0.9948
# Epoch 00015: val_f1_score improved from 0.77971 to 0.78000, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 117/117 [==============================] - 28s 242ms/step - loss: 0.0194 - accuracy: 0.9954 - f1_score: 0.9948 - val_loss: 0.9457 - val_accuracy: 0.7812 - val_f1_score: 0.7800 - lr: 3.9063e-06
# Epoch 16/25
# 117/117 [==============================] - ETA: 0s - loss: 0.0196 - accuracy: 0.9952 - f1_score: 0.9950
# Epoch 00016: val_f1_score improved from 0.78000 to 0.78160, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 117/117 [==============================] - 29s 244ms/step - loss: 0.0196 - accuracy: 0.9952 - f1_score: 0.9950 - val_loss: 0.9458 - val_accuracy: 0.7780 - val_f1_score: 0.7816 - lr: 3.9063e-06
# Epoch 17/25
# 117/117 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9960 - f1_score: 0.9957
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 00017: val_f1_score improved from 0.78160 to 0.78475, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 117/117 [==============================] - 28s 242ms/step - loss: 0.0228 - accuracy: 0.9960 - f1_score: 0.9957 - val_loss: 0.9395 - val_accuracy: 0.7856 - val_f1_score: 0.7847 - lr: 3.9063e-06
# Epoch 18/25
# 117/117 [==============================] - ETA: 0s - loss: 0.0211 - accuracy: 0.9949 - f1_score: 0.9938
# Epoch 00018: val_f1_score did not improve from 0.78475
# 117/117 [==============================] - 25s 210ms/step - loss: 0.0211 - accuracy: 0.9949 - f1_score: 0.9938 - val_loss: 0.9420 - val_accuracy: 0.7812 - val_f1_score: 0.7830 - lr: 1.0000e-06
# Epoch 19/25
# 117/117 [==============================] - ETA: 0s - loss: 0.0208 - accuracy: 0.9954 - f1_score: 0.9958
# Epoch 00019: val_f1_score did not improve from 0.78475
# 117/117 [==============================] - 25s 210ms/step - loss: 0.0208 - accuracy: 0.9954 - f1_score: 0.9958 - val_loss: 0.9422 - val_accuracy: 0.7834 - val_f1_score: 0.7834 - lr: 1.0000e-06
# Epoch 20/25
# 117/117 [==============================] - ETA: 0s - loss: 0.0172 - accuracy: 0.9960 - f1_score: 0.9958
# Epoch 00020: val_f1_score did not improve from 0.78475
# 117/117 [==============================] - 25s 210ms/step - loss: 0.0172 - accuracy: 0.9960 - f1_score: 0.9958 - val_loss: 0.9445 - val_accuracy: 0.7823 - val_f1_score: 0.7835 - lr: 1.0000e-06
# Epoch 21/25
# 117/117 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9962 - f1_score: 0.9961
# Epoch 00021: val_f1_score improved from 0.78475 to 0.78568, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 117/117 [==============================] - 28s 243ms/step - loss: 0.0193 - accuracy: 0.9962 - f1_score: 0.9961 - val_loss: 0.9422 - val_accuracy: 0.7856 - val_f1_score: 0.7857 - lr: 1.0000e-06
# Epoch 22/25
# 117/117 [==============================] - ETA: 0s - loss: 0.0187 - accuracy: 0.9962 - f1_score: 0.9957
# Epoch 00022: val_f1_score did not improve from 0.78568
# 117/117 [==============================] - 25s 210ms/step - loss: 0.0187 - accuracy: 0.9962 - f1_score: 0.9957 - val_loss: 0.9446 - val_accuracy: 0.7834 - val_f1_score: 0.7839 - lr: 1.0000e-06
# Epoch 23/25
# 117/117 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 0.9962 - f1_score: 0.9945
# Epoch 00023: val_f1_score did not improve from 0.78568
# 117/117 [==============================] - 25s 210ms/step - loss: 0.0200 - accuracy: 0.9962 - f1_score: 0.9945 - val_loss: 0.9456 - val_accuracy: 0.7834 - val_f1_score: 0.7839 - lr: 1.0000e-06
# Epoch 24/25
# 117/117 [==============================] - ETA: 0s - loss: 0.0170 - accuracy: 0.9968 - f1_score: 0.9969
# Epoch 00024: val_f1_score did not improve from 0.78568
# 117/117 [==============================] - 25s 210ms/step - loss: 0.0170 - accuracy: 0.9968 - f1_score: 0.9969 - val_loss: 0.9457 - val_accuracy: 0.7823 - val_f1_score: 0.7851 - lr: 1.0000e-06
# Epoch 25/25
# 117/117 [==============================] - ETA: 0s - loss: 0.0173 - accuracy: 0.9968 - f1_score: 0.9959
# Epoch 00025: val_f1_score did not improve from 0.78568
# 117/117 [==============================] - 25s 210ms/step - loss: 0.0173 - accuracy: 0.9968 - f1_score: 0.9959 - val_loss: 0.9438 - val_accuracy: 0.7823 - val_f1_score: 0.7851 - lr: 1.0000e-06

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 5))
plt.subplot(121)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1_score')
plt.ylabel('F1_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation f1_score
plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
results = model.evaluate(test_images, verbose=0)

print("    Test Loss: {:.5f}".format(results[0]))
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
#     Test Loss: 0.93145
# Test Accuracy: 78.12%

# %%
pred = model.predict(test_images)
pred = np.argmax(pred,axis=1)

# Map the label
labels = (train_images.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
y_test = list(test_df.Target)
cf_matrix = confusion_matrix(y_test, pred,normalize='true')
plt.figure(figsize = (10,6))
cmap=sns.light_palette("green")
sns.heatmap(cf_matrix,cmap=cmap, annot=True, xticklabels = sorted(set(y_test)), yticklabels = sorted(set(y_test)))
plt.title('Normalized Confusion Matrix')
plt.show()

# %%
fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(15, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(INPUT_PATH+'/'+test_df.image.iloc[i]))
    ax.set_title(f"True: {test_df.Target.iloc[i]}\nPredicted: {pred[i]}")
plt.tight_layout()
plt.show()
