# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
data=pd.read_csv('/content/gdrive/MyDrive/train/train.csv')
data.head()
# Out:
#          image  category
# 0  2823080.jpg         1
# 1  2870024.jpg         1
# 2  2662125.jpg         2
# 3  2900420.jpg         3
# 4  2804883.jpg         2

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

# %%
ship= {'Cargo': 1, 
        'Military': 2, 
        'Carrier': 3, 
        'Cruise': 4, 
        'Tankers': 5}

# reverse the ship type dictionary

ship = dict([[v,k] for k,v in ship.items()])
data['Target']=data['category'].map(ship).astype('category')
data.head()
# Out:
#          image  category    Target
# 0  2823080.jpg         1     Cargo
# 1  2870024.jpg         1     Cargo
# 2  2662125.jpg         2  Military
# 3  2900420.jpg         3   Carrier
# 4  2804883.jpg         2  Military

# %%
plt.figure(figsize=(10,10))
sns.countplot(y=data['Target'].values)
plt.xticks(rotation=90)
# Out:
# (array([   0.,  250.,  500.,  750., 1000., 1250., 1500., 1750., 2000.,
#         2250.]), <a list of 10 Text major ticklabel objects>)

# %%
from sklearn.model_selection import train_test_split
train_df,test_df=train_test_split(data,test_size=0.25,random_state=42)

# %%
import tensorflow as tf
from keras import backend as K
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.models import *
from tensorflow.keras.preprocessing.image import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.applications.efficientnet import *

# %%
print('Train Data',train_df.shape)
print('Test Data',test_df.shape)
# Out:
# Train Data (4689, 3)
# Test Data (1563, 3)

# %%
INPUT_PATH='/content/gdrive/MyDrive/train/images'
import random as rn
import cv2
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=rn.randint(0,data.shape[0])
        img = cv2.imread(INPUT_PATH+'/'+data.iloc[l][0],cv2.IMREAD_COLOR)
        img = cv2.resize(img, (224,224))
        ax[i,j].imshow(img)
        ax[i,j].set_title('Ship: '+data.iloc[l][2])
plt.tight_layout()

# %% [markdown]
# ## Apply Augmentation

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input,
    validation_split=0.2,featurewise_center=False,
                             featurewise_std_normalization=False,
                             rotation_range=10,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             horizontal_flip=True,
                             vertical_flip=True,
                             zoom_range=(0.8, 1.2),
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input,featurewise_center=False,
                             featurewise_std_normalization=False,
                             rotation_range=10,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             horizontal_flip=True,
                             vertical_flip=True,
                             zoom_range=(0.8, 1.2),
)

# %%
train_images_aug = train_generator.flow_from_dataframe(
    dataframe=train_df,
    directory=INPUT_PATH,
    x_col='image',
    y_col='Target',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=256,
    shuffle=True,
    seed=42,
    subset='training'
)

val_images_aug = train_generator.flow_from_dataframe(
    dataframe=train_df,
    directory=INPUT_PATH,
    x_col='image',
    y_col='Target',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=256,
    shuffle=True,
    seed=42,
    subset='validation'
)

test_images_aug = test_generator.flow_from_dataframe(
    dataframe=test_df,
    directory=INPUT_PATH,
    x_col='image',
    y_col='Target',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=256,
    shuffle=False
)
# Out:
# Found 3752 validated image filenames belonging to 5 classes.
# Found 937 validated image filenames belonging to 5 classes.
# Found 1563 validated image filenames belonging to 5 classes.

# %% [markdown]
# **Metrics(F1_Score)**

# %%
def f1_score(y_true, y_pred):
    def recall(y_true, y_pred):
        """Recall metric.
        Only computes a batch-wise average of recall.
        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        """Precision metric.
        Only computes a batch-wise average of precision.
        Computes the precision, a metric for multi-label classification of
        how many selected items are relevant.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# #Pretrained VGG16

# %%
def create_model_inception(input_shape):
  base_model_inception = tf.keras.applications.inception_v3.InceptionV3(include_top=False, classes=5)
  inputs =Input(shape=(224,224,3), name='input_layer')
  #Scaling the values
  x = tf.keras.layers.experimental.preprocessing.Rescaling(1/255.)(inputs)
  #Pass inputs to our base_model
  x = base_model_inception(inputs,training=False)
  # GlobalAveragePooling2D
  Conv1 = Conv2D(filters=32,kernel_size=(3,3),strides=(1,1),padding='valid',data_format='channels_last',
              activation='relu',kernel_initializer=tf.keras.initializers.glorot_normal(seed=32),name='Conv1')(x)
  #Batch Norm
  BN1=BatchNormalization()(Conv1)
  #MaxPool Layer
  Pool1 = MaxPool2D(pool_size=(2,2),strides=(2,2),padding='valid',data_format='channels_last',name='Pool1')(BN1)

  #Flatten
  flatten = Flatten(data_format='channels_last',name='Flatten')(Pool1)

  #Dropout
  DO1=Dropout(0.2)(flatten)
  #FC layer
  FC1 = Dense(units=50,activation='relu',kernel_initializer=tf.keras.initializers.glorot_normal(seed=32),name='FC1')(DO1)
  DO2=Dropout(0.2)(FC1)
  #FC layer
  FC2 = Dense(units=30,activation='relu',kernel_initializer=tf.keras.initializers.glorot_normal(seed=33),name='FC2')(DO2)

  #output layer
  Out = Dense(units=5,activation='softmax',kernel_initializer=tf.keras.initializers.glorot_normal(seed=3),name='Output')(FC2)
  # Build model
  model= Model(inputs, Out)
  return model

# %%
model=create_model_inception(input_shape=(224,224,3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# 87924736/87910968 [==============================] - 1s 0us/step

# %%
tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True,
rankdir='TB')

# %%
model.compile(loss='categorical_crossentropy',
               optimizer='adam',
               metrics=['accuracy',f1_score])

# %%
from tensorflow.keras.callbacks import *
import os
# %reload_ext tensorboard
filepath="/content/gdrive/MyDrive/Flower dataset/"
checkpoint = ModelCheckpoint(monitor='val_f1_score', mode='max', filepath=filepath, verbose=1, save_best_only=True, save_weights_only=False)
earlystop = EarlyStopping(monitor = 'val_f1_score',  mode="max",min_delta = 0, patience = 6,verbose = 1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_f1_score', factor = 0.25, patience = 3, verbose = 1,min_lr=0.000001)
import datetime
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
#tensorboard = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)
tensorboard = TensorBoard(log_dir=logdir, histogram_freq=0, write_graph=True, write_grads=False, write_images=False)
callbacks = [reduce_lr,tensorboard,checkpoint,earlystop]

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
STEP_SIZE_TRAIN=train_images_aug.n//train_images_aug.batch_size
STEP_SIZE_VALID=val_images_aug.n//val_images_aug.batch_size
STEP_SIZE_TEST=test_images_aug.n//test_images_aug.batch_size
history=model.fit_generator(generator=train_images_aug,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=test_images_aug,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=25,callbacks=callbacks)
# Out:
# Epoch 1/25
# 14/14 [==============================] - ETA: 0s - loss: 1.6541 - accuracy: 0.2786 - f1_score: 0.0226
# Epoch 00001: val_f1_score improved from -inf to 0.32422, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 14/14 [==============================] - 1472s 105s/step - loss: 1.6541 - accuracy: 0.2786 - f1_score: 0.0226 - val_loss: 43.7374 - val_accuracy: 0.3242 - val_f1_score: 0.3242 - lr: 0.0010
# Epoch 2/25
# 14/14 [==============================] - ETA: 0s - loss: 1.4782 - accuracy: 0.3850 - f1_score: 0.1180
# Epoch 00002: val_f1_score did not improve from 0.32422
# 14/14 [==============================] - 64s 5s/step - loss: 1.4782 - accuracy: 0.3850 - f1_score: 0.1180 - val_loss: 1231190.0000 - val_accuracy: 0.1810 - val_f1_score: 0.1810 - lr: 0.0010
# Epoch 3/25
# 14/14 [==============================] - ETA: 0s - loss: 1.3843 - accuracy: 0.4302 - f1_score: 0.2506
# Epoch 00003: val_f1_score did not improve from 0.32422
# 14/14 [==============================] - 56s 4s/step - loss: 1.3843 - accuracy: 0.4302 - f1_score: 0.2506 - val_loss: 21.1699 - val_accuracy: 0.3242 - val_f1_score: 0.3242 - lr: 0.0010
# Epoch 4/25
# 14/14 [==============================] - ETA: 0s - loss: 1.3275 - accuracy: 0.4376 - f1_score: 0.3141
# Epoch 00004: val_f1_score did not improve from 0.32422
# 14/14 [==============================] - 64s 5s/step - loss: 1.3275 - accuracy: 0.4376 - f1_score: 0.3141 - val_loss: 21.0368 - val_accuracy: 0.3242 - val_f1_score: 0.3242 - lr: 0.0010
# Epoch 5/25
# 14/14 [==============================] - ETA: 0s - loss: 1.2626 - accuracy: 0.4465 - f1_score: 0.3329
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00005: val_f1_score did not improve from 0.32422
# 14/14 [==============================] - 64s 5s/step - loss: 1.2626 - accuracy: 0.4465 - f1_score: 0.3329 - val_loss: 9.5654 - val_accuracy: 0.3242 - val_f1_score: 0.3242 - lr: 0.0010
# Epoch 6/25
# 14/14 [==============================] - ETA: 0s - loss: 1.2384 - accuracy: 0.4565 - f1_score: 0.3680
# Epoch 00006: val_f1_score did not improve from 0.32422
# 14/14 [==============================] - 64s 5s/step - loss: 1.2384 - accuracy: 0.4565 - f1_score: 0.3680 - val_loss: 4.7356 - val_accuracy: 0.3242 - val_f1_score: 0.3242 - lr: 2.5000e-04
# Epoch 7/25
# 14/14 [==============================] - ETA: 0s - loss: 1.2006 - accuracy: 0.4714 - f1_score: 0.3841
# Epoch 00007: val_f1_score improved from 0.32422 to 0.32524, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 14/14 [==============================] - 106s 8s/step - loss: 1.2006 - accuracy: 0.4714 - f1_score: 0.3841 - val_loss: 2.8002 - val_accuracy: 0.3255 - val_f1_score: 0.3252 - lr: 2.5000e-04
# Epoch 8/25
# 14/14 [==============================] - ETA: 0s - loss: 1.1821 - accuracy: 0.4677 - f1_score: 0.3774
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00008: val_f1_score did not improve from 0.32524
# 14/14 [==============================] - 64s 5s/step - loss: 1.1821 - accuracy: 0.4677 - f1_score: 0.3774 - val_loss: 5.0049 - val_accuracy: 0.3242 - val_f1_score: 0.3242 - lr: 2.5000e-04
# Epoch 9/25
# 14/14 [==============================] - ETA: 0s - loss: 1.1950 - accuracy: 0.4665 - f1_score: 0.3749
# Epoch 00009: val_f1_score improved from 0.32524 to 0.35542, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 14/14 [==============================] - 106s 8s/step - loss: 1.1950 - accuracy: 0.4665 - f1_score: 0.3749 - val_loss: 1.8384 - val_accuracy: 0.3333 - val_f1_score: 0.3554 - lr: 6.2500e-05
# Epoch 10/25
# 14/14 [==============================] - ETA: 0s - loss: 1.1762 - accuracy: 0.4740 - f1_score: 0.3748
# Epoch 00010: val_f1_score did not improve from 0.35542
# 14/14 [==============================] - 64s 5s/step - loss: 1.1762 - accuracy: 0.4740 - f1_score: 0.3748 - val_loss: 1.8184 - val_accuracy: 0.3320 - val_f1_score: 0.3510 - lr: 6.2500e-05
# Epoch 11/25
# 14/14 [==============================] - ETA: 0s - loss: 1.1621 - accuracy: 0.4823 - f1_score: 0.3808
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00011: val_f1_score improved from 0.35542 to 0.35763, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 14/14 [==============================] - 107s 8s/step - loss: 1.1621 - accuracy: 0.4823 - f1_score: 0.3808 - val_loss: 1.6932 - val_accuracy: 0.3411 - val_f1_score: 0.3576 - lr: 6.2500e-05
# Epoch 12/25
# 14/14 [==============================] - ETA: 0s - loss: 1.1590 - accuracy: 0.4740 - f1_score: 0.3838
# Epoch 00012: val_f1_score did not improve from 0.35763
# 14/14 [==============================] - 64s 5s/step - loss: 1.1590 - accuracy: 0.4740 - f1_score: 0.3838 - val_loss: 1.3286 - val_accuracy: 0.3997 - val_f1_score: 0.3435 - lr: 1.5625e-05
# Epoch 13/25
# 14/14 [==============================] - ETA: 0s - loss: 1.1630 - accuracy: 0.4728 - f1_score: 0.3917
# Epoch 00013: val_f1_score improved from 0.35763 to 0.36308, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 14/14 [==============================] - 100s 7s/step - loss: 1.1630 - accuracy: 0.4728 - f1_score: 0.3917 - val_loss: 1.2493 - val_accuracy: 0.4284 - val_f1_score: 0.3631 - lr: 1.5625e-05
# Epoch 14/25
# 14/14 [==============================] - ETA: 0s - loss: 1.1554 - accuracy: 0.4777 - f1_score: 0.3845
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 00014: val_f1_score improved from 0.36308 to 0.36759, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 14/14 [==============================] - 107s 8s/step - loss: 1.1554 - accuracy: 0.4777 - f1_score: 0.3845 - val_loss: 1.1800 - val_accuracy: 0.4505 - val_f1_score: 0.3676 - lr: 1.5625e-05
# Epoch 15/25
# 14/14 [==============================] - ETA: 0s - loss: 1.1524 - accuracy: 0.4748 - f1_score: 0.3968
# Epoch 00015: val_f1_score improved from 0.36759 to 0.36989, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 14/14 [==============================] - 109s 8s/step - loss: 1.1524 - accuracy: 0.4748 - f1_score: 0.3968 - val_loss: 1.1759 - val_accuracy: 0.4518 - val_f1_score: 0.3699 - lr: 3.9063e-06
# Epoch 16/25
# 14/14 [==============================] - ETA: 0s - loss: 1.1495 - accuracy: 0.4871 - f1_score: 0.3901
# Epoch 00016: val_f1_score did not improve from 0.36989
# 14/14 [==============================] - 64s 5s/step - loss: 1.1495 - accuracy: 0.4871 - f1_score: 0.3901 - val_loss: 1.1977 - val_accuracy: 0.4440 - val_f1_score: 0.3637 - lr: 3.9063e-06
# Epoch 17/25
# 14/14 [==============================] - ETA: 0s - loss: 1.1495 - accuracy: 0.4791 - f1_score: 0.3910
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 00017: val_f1_score improved from 0.36989 to 0.37019, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 14/14 [==============================] - 100s 7s/step - loss: 1.1495 - accuracy: 0.4791 - f1_score: 0.3910 - val_loss: 1.1651 - val_accuracy: 0.4531 - val_f1_score: 0.3702 - lr: 3.9063e-06
# Epoch 18/25
# 14/14 [==============================] - ETA: 0s - loss: 1.1562 - accuracy: 0.4791 - f1_score: 0.3806
# Epoch 00018: val_f1_score did not improve from 0.37019
# 14/14 [==============================] - 57s 4s/step - loss: 1.1562 - accuracy: 0.4791 - f1_score: 0.3806 - val_loss: 1.1744 - val_accuracy: 0.4531 - val_f1_score: 0.3585 - lr: 1.0000e-06
# Epoch 19/25
# 14/14 [==============================] - ETA: 0s - loss: 1.1567 - accuracy: 0.4800 - f1_score: 0.3930
# Epoch 00019: val_f1_score improved from 0.37019 to 0.37115, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 14/14 [==============================] - 106s 8s/step - loss: 1.1567 - accuracy: 0.4800 - f1_score: 0.3930 - val_loss: 1.1653 - val_accuracy: 0.4609 - val_f1_score: 0.3711 - lr: 1.0000e-06
# Epoch 20/25
# 14/14 [==============================] - ETA: 0s - loss: 1.1534 - accuracy: 0.4783 - f1_score: 0.3987
# Epoch 00020: val_f1_score did not improve from 0.37115
# 14/14 [==============================] - 65s 5s/step - loss: 1.1534 - accuracy: 0.4783 - f1_score: 0.3987 - val_loss: 1.1540 - val_accuracy: 0.4609 - val_f1_score: 0.3705 - lr: 1.0000e-06
# Epoch 21/25
# 14/14 [==============================] - ETA: 0s - loss: 1.1540 - accuracy: 0.4823 - f1_score: 0.3905
# Epoch 00021: val_f1_score did not improve from 0.37115
# 14/14 [==============================] - 64s 5s/step - loss: 1.1540 - accuracy: 0.4823 - f1_score: 0.3905 - val_loss: 1.1540 - val_accuracy: 0.4648 - val_f1_score: 0.3701 - lr: 1.0000e-06
# Epoch 22/25
# 14/14 [==============================] - ETA: 0s - loss: 1.1528 - accuracy: 0.4823 - f1_score: 0.3822
# Epoch 00022: val_f1_score did not improve from 0.37115
# 14/14 [==============================] - 64s 5s/step - loss: 1.1528 - accuracy: 0.4823 - f1_score: 0.3822 - val_loss: 1.1501 - val_accuracy: 0.4661 - val_f1_score: 0.3669 - lr: 1.0000e-06
# Epoch 23/25
# 14/14 [==============================] - ETA: 0s - loss: 1.1478 - accuracy: 0.4868 - f1_score: 0.3826
# Epoch 00023: val_f1_score improved from 0.37115 to 0.37632, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 14/14 [==============================] - 99s 7s/step - loss: 1.1478 - accuracy: 0.4868 - f1_score: 0.3826 - val_loss: 1.1433 - val_accuracy: 0.4727 - val_f1_score: 0.3763 - lr: 1.0000e-06
# Epoch 24/25
# 14/14 [==============================] - ETA: 0s - loss: 1.1445 - accuracy: 0.4808 - f1_score: 0.3943
# Epoch 00024: val_f1_score improved from 0.37632 to 0.37886, saving model to /content/gdrive/MyDrive/Flower dataset/
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Flower dataset/assets
# 14/14 [==============================] - 99s 7s/step - loss: 1.1445 - accuracy: 0.4808 - f1_score: 0.3943 - val_loss: 1.1508 - val_accuracy: 0.4661 - val_f1_score: 0.3789 - lr: 1.0000e-06
# Epoch 25/25
# 14/14 [==============================] - ETA: 0s - loss: 1.1469 - accuracy: 0.4834 - f1_score: 0.4033
# Epoch 00025: val_f1_score did not improve from 0.37886
# 14/14 [==============================] - 57s 4s/step - loss: 1.1469 - accuracy: 0.4834 - f1_score: 0.4033 - val_loss: 1.1569 - val_accuracy: 0.4727 - val_f1_score: 0.3544 - lr: 1.0000e-06

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 5))
plt.subplot(121)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1_score')
plt.ylabel('F1_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation f1_score
plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
pred = model.predict(test_images_aug)
pred = np.argmax(pred,axis=1)

# Map the label
labels = (train_images_aug.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
y_test = list(test_df.Target)
cf_matrix = confusion_matrix(y_test, pred,normalize='true')
plt.figure(figsize = (10,6))
cmap=sns.light_palette("green")
sns.heatmap(cf_matrix,cmap=cmap, annot=True, xticklabels = sorted(set(y_test)), yticklabels = sorted(set(y_test)))
plt.title('Normalized Confusion Matrix')
plt.show()

# %%
fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(15, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(INPUT_PATH+'/'+test_df.image.iloc[i]))
    ax.set_title(f"True: {test_df.Target.iloc[i]}\nPredicted: {pred[i]}")
plt.tight_layout()
plt.show()
